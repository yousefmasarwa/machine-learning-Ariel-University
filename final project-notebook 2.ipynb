# %%
import pandas as pd
import matplotlib as pt
import numpy as np

# %%
print("Q1")
def dec_to_bin(x):
    return str(bin(x)[2:])

def dec_to_oct(x):
    return str(oct(x)[2:])
def dec_to_hex(x):
    return str(hex(x)[2:])

##main##
x= int(input("Enter your num: "))
print("base binary is: ",dec_to_bin(x))
print("base octal is: ",dec_to_oct(x))
print("base hex is: ",dec_to_hex(x))
# Out:
# Q1
# Enter your num: 5
# base binary is:  101
# base octal is:  5
# base hex is:  5

# %%
df=pd.read_csv(r"C:\Users\2031\Desktop\cast12.csv",parse_dates=['year'])
df
# Out:
#                           title       year                        name  \
# 0                Closet Monster 2015-01-01                    Buffy #1
# 1               Suuri illusioni 1985-01-01                      Homo $
# 2           Battle of the Sexes 2017-01-01                     $hutter
# 3          Secret in Their Eyes 2015-01-01                     $hutter
# 4                    Steve Jobs 2015-01-01                     $hutter
# ...                         ...        ...                         ...
# 74996  Mia fora kai ena... moro 2011-01-01     Penelope Anastasopoulou
# 74997         The Magician King 2004-01-01       Tiannah Anastassiades
# 74998        Festival of Lights 2010-01-01             Zoe Anastassiou
# 74999                Toxic Tutu 2016-01-01             Zoe Anastassiou
# 75000           Fugitive Pieces 2007-01-01  Anastassia Anastassopoulou
#
#           type                character     n
# 0        actor                  Buffy 4  31.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75001 entries, 0 to 75000
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      75001 non-null  object
#  1   year       75001 non-null  datetime64[ns]
#  2   name       75001 non-null  object
#  3   type       75001 non-null  object
#  4   character  75001 non-null  object
#  5   n          46035 non-null  float64
# dtypes: datetime64[ns](1), float64(1), object(4)
# memory usage: 3.4+ MB

# %%
reviews_from_critics=df['n'].groupby(df['year'])
reviews_from_critics.plot.line()
print(reviews_from_critics)

# %%
print("Q2")
df['movies who have the title hamlet'] = np.where(df['title']=='Hamlet', 1, 0)
print(df['movies who have the title hamlet'].value_counts())
df
# Out:
# Q2
# 0    74992
# 1        9
# Name: movies who have the title hamlet, dtype: int64
#                           title       year                        name  \
# 0                Closet Monster 2015-01-01                    Buffy #1
# 1               Suuri illusioni 1985-01-01                      Homo $
# 2           Battle of the Sexes 2017-01-01                     $hutter
# 3          Secret in Their Eyes 2015-01-01                     $hutter
# 4                    Steve Jobs 2015-01-01                     $hutter
# ...                         ...        ...                         ...
# 74996  Mia fora kai ena... moro 2011-01-01     Penelope Anastasopoulou
# 74997         The Magician King 2004-01-01       Tiannah Anastassiades
# 74998        Festival of Lights 2010-01-01             Zoe Anastassiou
# 74999                Toxic Tutu 2016-01-01             Zoe Anastassiou
# 75000           Fugitive Pieces 2007-01-01  Anastassia Anastassopoulou
#
# ...

# %%
df['title'].value_counts()
# Out:
# Thelma                                          47
# 7 cajas                                         32
# Around the World in Eighty Days                 26
# Zombadings 1: Patayin sa shokot si Remington    22
# Dekada '70                                      21
#                                                 ..
# Prasnam Gurutharam                               1
# Bewafaa                                          1
# The Middle Finger                                1
# Il venditore di morte                            1
# Autopsy                                          1
# Name: title, Length: 49323, dtype: int64

# %%
df.loc[df.year>'2010']
# Out:
#                           title       year                     name     type  \
# 0                Closet Monster 2015-01-01                 Buffy #1    actor
# 2           Battle of the Sexes 2017-01-01                  $hutter    actor
# 3          Secret in Their Eyes 2015-01-01                  $hutter    actor
# 4                    Steve Jobs 2015-01-01                  $hutter    actor
# 5        Straight Outta Compton 2015-01-01                  $hutter    actor
# ...                         ...        ...                      ...      ...
# 74989               High Strung 2016-01-01         Denisa Anastasiu  actress
# 74991         The Hanover House 2014-01-01         Jenny Anastasoff  actress
# 74993       I teliki apopliromi 2013-01-01      Mara Anastasopoulou  actress
# 74996  Mia fora kai ena... moro 2011-01-01  Penelope Anastasopoulou  actress
# 74999                Toxic Tutu 2016-01-01          Zoe Anastassiou  actress
#
# ...

# %%
df.loc[df.title=="Hamlet"]
# Out:
#         title       year              name   type              character  \
# 1643   Hamlet 1996-01-01        Riz Abbasi  actor  Attendant to Claudius
# 7543   Hamlet 1921-01-01  Fritz Achterberg  actor            Fortinbras,
# 11406  Hamlet 2009-01-01      Hayden Adams  actor                Laertes
# 11407  Hamlet 2009-01-01      Hayden Adams  actor                 Player
# 14100  Hamlet 1913-01-01       Eric Adeney  actor               Reynaldo
# 16297  Hamlet 2000-01-01     Casey Affleck  actor             Fortinbras
# 33353  Hamlet 1964-01-01    Hugh Alexander  actor              Cornelius
# 33354  Hamlet 1964-01-01    Hugh Alexander  actor     Second Gravedigger
# 33355  Hamlet 1964-01-01    Hugh Alexander  actor     English Ambassador
#
#           n  movies who have the title hamlet
# 1643    1.0                                 1
# 7543    9.0                                 1
# 11406   7.0                                 1
# 11407   7.0                                 1
# ...

# %%
ser=df.nunique()
print(ser['year'])
# Out:
# 110

# %%
df['year'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       2015-01-01
# 1       1985-01-01
# 2       2017-01-01
# 3       2015-01-01
# 4       2015-01-01
#            ...
# 74996   2011-01-01
# 74997   2004-01-01
# 74998   2010-01-01
# 74999   2016-01-01
# 75000   2007-01-01
# Name: year, Length: 75001, dtype: datetime64[ns]>

# %%
print("Q3")
df.sort_values(by=['year'])
df.loc[df.title=='Treasure Island']
# Out:
# Q3
#                  title       year                name     type  \
# 9570   Treasure Island 1934-01-01        Robert Adair    actor
# 13434  Treasure Island 1950-01-01        Chris Adcock    actor
# 16466  Treasure Island 1985-01-01         Yves Afonso    actor
# 42602  Treasure Island 1972-01-01  Cristino Almod?var    actor
# 66568  Treasure Island 1972-01-01               Alibe  actress
#
#             character     n  movies who have the title hamlet
# 9570     Tom - Seaman   NaN                                 0
# 13434            Pike  26.0                                 0
# 16466  French Captain   8.0                                 0
# 42602         O'Brien  16.0                                 0
# 66568     Mrs. Silver  12.0                                 0

# %%
df1=df.loc[df.year<'2000']
df.loc[df.title=='Hamlet']
# Out:
#         title       year              name   type              character  \
# 1643   Hamlet 1996-01-01        Riz Abbasi  actor  Attendant to Claudius
# 7543   Hamlet 1921-01-01  Fritz Achterberg  actor            Fortinbras,
# 11406  Hamlet 2009-01-01      Hayden Adams  actor                Laertes
# 11407  Hamlet 2009-01-01      Hayden Adams  actor                 Player
# 14100  Hamlet 1913-01-01       Eric Adeney  actor               Reynaldo
# 16297  Hamlet 2000-01-01     Casey Affleck  actor             Fortinbras
# 33353  Hamlet 1964-01-01    Hugh Alexander  actor              Cornelius
# 33354  Hamlet 1964-01-01    Hugh Alexander  actor     Second Gravedigger
# 33355  Hamlet 1964-01-01    Hugh Alexander  actor     English Ambassador
#
#           n  movies who have the title hamlet
# 1643    1.0                                 1
# 7543    9.0                                 1
# 11406   7.0                                 1
# 11407   7.0                                 1
# ...

# %%
g=df.groupby('title')
print(g)

# %%
df2=df.loc[df.year=='1921']
df2
# Out:
#                               title       year                   name  \
# 292         The Chicken in the Case 1921-01-01           Linus Aaberg
# 1178            Arsena Jorjiashvili 1921-01-01         Vaso Abashidze
# 1735                    Cappy Ricks 1921-01-01        Charles S. Abbe
# 1739         The Conquest of Canaan 1921-01-01        Charles S. Abbe
# 2008                    The Raiders 1921-01-01              H. Abbott
# ...                             ...        ...                    ...
# 69020             Ce que femme veut 1921-01-01  Mademoiselle Allen?on
# 69352                      Big Game 1921-01-01            May Allison
# 69356                  Extravagance 1921-01-01            May Allison
# 69381  The Marriage of William Ashe 1921-01-01            May Allison
# 72905       Froggy's Little Brother 1921-01-01          Violet Ambert
#
#           type           character     n  movies who have the title hamlet
# ...

# %%
print("Q3")
df3=df2.loc[df.title=='Hamlet']

print(df3,
      "there are 9 roles were credited in the silent version of 'Hamlet'")
# Out:
# Q3
#        title       year              name   type    character    n  \
# 7543  Hamlet 1921-01-01  Fritz Achterberg  actor  Fortinbras,  9.0
#
#       movies who have the title hamlet
# 7543                                 1   there are 9 roles were credited in the silent version of 'Hamlet'

# %%
print("Q4")
hamlet_mo=df.loc[df.title=="Hamlet"]
g=hamlet_mo.groupby("year")
g.size().plot()
# Out:
# Q4

# %%
df4=df.loc[df.year<'1960']
df5=df4.loc[df4.year>'1949']
g1=df5.groupby('type').n.describe()
print(g1)
# Out:
#           count      mean       std  min  25%  50%   75%    max
# type
# actor    1490.0  8.575168  7.263998  1.0  4.0  7.0  11.0   67.0
# actress   665.0  7.885714  9.241515  1.0  2.0  6.0  11.0  159.0

# %%
df['cumsum_2'] = df[['n','type']].groupby('type').cumsum()
df
# Out:
#                           title       year                        name  \
# 0                Closet Monster 2015-01-01                    Buffy #1
# 1               Suuri illusioni 1985-01-01                      Homo $
# 2           Battle of the Sexes 2017-01-01                     $hutter
# 3          Secret in Their Eyes 2015-01-01                     $hutter
# 4                    Steve Jobs 2015-01-01                     $hutter
# ...                         ...        ...                         ...
# 74996  Mia fora kai ena... moro 2011-01-01     Penelope Anastasopoulou
# 74997         The Magician King 2004-01-01       Tiannah Anastassiades
# 74998        Festival of Lights 2010-01-01             Zoe Anastassiou
# 74999                Toxic Tutu 2016-01-01             Zoe Anastassiou
# 75000           Fugitive Pieces 2007-01-01  Anastassia Anastassopoulou
#
#           type                character     n  \
# 0        actor                  Buffy 4  31.0
# ...

# %%
print("Q5")
n = ['1']
df5[df5.n.isin(n)]
g1=df5.groupby('type').n.describe()
print(g1)
# Out:
# Q5
#           count      mean       std  min  25%  50%   75%    max
# type
# actor    1490.0  8.575168  7.263998  1.0  4.0  7.0  11.0   67.0
# actress   665.0  7.885714  9.241515  1.0  2.0  6.0  11.0  159.0

# %%
print("Q6")
df6=df.loc[df.year>'1899']
df8=df6.loc[df.n==1]
df8.name.value_counts().head(10)
# Out:
# Q6
# Nagarjuna Akkineni    72
# Antonio Aguilar       61
# Luis Aguilar          55
# Sadri Alisik          43
# Bud Abbott            39
# Mario Almada          36
# Diego Abatantuono     34
# Art Acord             31
# Tarik Akan            30
# Hans Albers           30
# Name: name, dtype: int64

# %%
df6.sort_values(by=['n'])
# Out:
#                                title       year                        name  \
# 37383                        Soytari 1965-01-01                Sadri Alisik
# 62324                       Sin City 2005-01-01                Jessica Alba
# 69352                       Big Game 1921-01-01                 May Allison
# 37522             The Package Vol. 1 2010-01-01              BeMo Aljefairi
# 37529  3 Chinesen mit dem Kontrabass 2000-01-01             Boris Aljinovic
# ...                              ...        ...                         ...
# 74984                           Ovum 2015-01-01  Christina Rosas Anastasiou
# 74985                         7 avlu 2009-01-01         Evmorfia Anastasiou
# 74993            I teliki apopliromi 2013-01-01         Mara Anastasopoulou
# 74997              The Magician King 2004-01-01       Tiannah Anastassiades
# 74999                     Toxic Tutu 2016-01-01             Zoe Anastassiou
#
#           type                      character    n  \
# ...

# %%
g2=df6.groupby('name').n.describe()
g2
# Out:
#                   count  mean      std   min    25%   50%    75%   max
# name
# $hutter             1.0  10.0      NaN  10.0  10.00  10.0  10.00  10.0
# 'Babe' Agamenoni    0.0   NaN      NaN   NaN    NaN   NaN    NaN   NaN
# 'Babe' Agaminono    0.0   NaN      NaN   NaN    NaN   NaN    NaN   NaN
# 'El Guisa'          1.0  25.0      NaN  25.0  25.00  25.0  25.00  25.0
# 'El Viti'           1.0  20.0      NaN  20.0  20.00  20.0  20.00  20.0
# ...                 ...   ...      ...   ...    ...   ...    ...   ...
# Zura Abesadze       1.0   9.0      NaN   9.0   9.00   9.0   9.00   9.0
# Zuri Alexander      0.0   NaN      NaN   NaN    NaN   NaN    NaN   NaN
# Zuzu Abu            1.0  22.0      NaN  22.0  22.00  22.0  22.00  22.0
# Zvone Agrez         2.0   6.5  2.12132   5.0   5.75   6.5   7.25   8.0
# gregg Alexander     0.0   NaN      NaN   NaN    NaN   NaN    NaN   NaN
#
# [29319 rows x 8 columns]

# %%
#Q7
df7=df.sort_values(by=['year'])
df7.loc[df.type=='Frank Oz']
# Out:
# Empty DataFrame
# Columns: [title, year, name, type, character, n, movies who have the title hamlet, cumsum_2]
# Index: []
